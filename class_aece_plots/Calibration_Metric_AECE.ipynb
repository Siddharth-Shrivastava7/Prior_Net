# %%
import glob
import numpy as np
import ipyplot
imglist = sorted(glob.glob('*.png'))
imgarr = np.array(imglist)
ipyplot.plot_images(imgarr, max_images=imgarr.shape[0], img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-FSta8KRMDmDKV4p8fAq3Ww {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-FSta8KRMDmDKV4p8fAq3Ww {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-FSta8KRMDmDKV4p8fAq3Ww {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-FSta8KRMDmDKV4p8fAq3Ww:checked ~ #ipyplot-html-viewer-textarea-FSta8KRMDmDKV4p8fAq3Ww {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-FSta8KRMDmDKV4p8fAq3Ww:checked + #ipyplot-html-viewer-label-FSta8KRMDmDKV4p8fAq3Ww:after {
# ...
